# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pathlib as pl

# %%
#nyquist plot
root = pl.Path("D:/Linh Python/Cosodien")
filename = root / "c2.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)
match int(df['state'][0]):
    case 0: state_label = "ngay 1"
    case 1: state_label = "ngay 2"
    case 2: state_label = "ngam"

state = '0_0'
fig, ax = plt.subplots()
for i in range(3, 6):

    f_data = df[(df['type'] == 'doc') & (df['state'] == state) & (df['sample'] == i) & (df['freq']>30)]
    # f_data['freq'] = [20, 200, 2000, 20000, 200000][:len(f_data)]

    f_data.plot(x='freq', y='Im(Z)', legend=True, label=f'sample {i}', ax=ax, grid=True, logx=True,
    ylabel='-Im(Z)', xlabel='freq(Hz)')

# %%
filename = root / "c2.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'Z', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)
df["phase"] = df["phase"] * (-1)
match int(df['state'][0]):
    case 0: state_label = "ngay 1"
    case 1: state_label = "ngay 2"
    case 2: state_label = "ngam"

state_list = ['0_0', '1_0', '2_0']
for k in range(1, 11):
    fig, ax = plt.subplots()
    for i in range(len(state_list)):

        f_data = df[(df['type'] == 'doc') & (df['state'] == state_list[i]) & (df['sample'] == k)]

        f_data.plot(x='freq', y='phase', legend=True, label=f'{i}_0', ax=ax, grid=True,
        xlabel='freq', ylabel='phase(deg)', logx=True)
        fig.savefig(root / f'phase/ga/sample{k}.png')

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 27
#      25 # Apply smoothing
#      26 freq = f_data['freq'].values
# ---> 27 re_z = moving_average(f_data['Re(Z)'].values)
#      28 im_z = moving_average(f_data['Im(Z)'].values)
#      30 ax.plot(freq, re_z, label=f'{state}', marker='o')
#
# Cell In[5], line 6, in moving_average(data, window_size)
#       5 def moving_average(data, window_size=5):
# ----> 6     return np.convolve(data, np.ones(window_size)/window_size, mode='same')
#
# File D:\Linh Python\CoSoDien\.venv\Lib\site-packages\numpy\_core\numeric.py:868, in convolve(a, v, mode)
#     866     raise ValueError('a cannot be empty')
#     867 if len(v) == 0:
# --> 868     raise ValueError('v cannot be empty')
#     869 return multiarray.correlate(a, v[::-1], mode)
#
# ValueError: v cannot be empty

# %%
#magnitude bode plot
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'Z', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)

state = '0_0'
state_list = ['0_0', '1_0', '2_0']
df['freq'] = pd.to_numeric(df['freq'], errors='coerce')
fig, ax = plt.subplots()
for i in range(1, 9):

    f_data = df[(df['type'] == 'doc') & (df['state'] == state) & (df['sample'] == i) & (df['freq'] > 40)]

    f_data.plot(x='freq', y='Z', legend=True, label=f'{i}_0', ax=ax, grid=True,
    xlabel='freq', ylabel='phase(deg)', logx=True)

# %%
# root = pl.Path("D:/Linh Python/Cosodien")
filename = root / "p2.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df['Im(Z)'] = df['Im(Z)'] * (-1)
df['freq'] = pd.to_numeric(df['freq'], errors='coerce')
state_list = ['0_0', '1_0', '2_0']
# fig, ax = plt.subplots()
# fig1, ax1 = plt.subplots()
for k in range(1, 11):
    fig, ax = plt.subplots()
    fig1, ax1 = plt.subplots()
    for i in range(len(state_list)):

        f_data = df[(df['type'] == 'doc') & (df['state'] == state_list[i]) & (df['sample'] == k)]

        # f_data.plot(x='freq', y='Im(Z)', legend=True, label=f'-Im(Z)', ax=ax, grid=True, marker='o', logx=True)
        f_data.plot(x='freq', y='Re(Z)', legend=True, label=f'{state_list[i]}', ax=ax, grid=True, logx=True, ylabel='Re(Z)', xlabel='freq(Hz)', marker='o')
        # fig.savefig(root / f"magnitude/lon/Re{k}.png")

    for i in range(len(state_list)):

        f_data = df[(df['type'] == 'doc') & (df['state'] == state_list[i]) & (df['sample'] == k) & (df['freq'] > 30)]

        # f_data.plot(x='freq', y='Im(Z)', legend=True, label=f'-Im(Z)', ax=ax, grid=True, marker='o', logx=True)
        f_data.plot(x='freq', y='Im(Z)', legend=True, label=f'{state_list[i]}', ax=ax1, grid=True, logx=True, ylabel='-Im(Z)', xlabel='freq(Hz)', marker='o')
        # fig.savefig(root / f"magnitude/lon/Im{k}.png")

# %%
filename = root / "p2.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)

state = '0_0'
for i in range(1, 11):
    fig, ax = plt.subplots()
    f_data = df[(df['type'] == 'doc') & (df['state'] == state) & (df['sample'] == i)]

    f_data.plot.scatter(x='Re(Z)', y='Im(Z)', legend=True, label=f'sample', ax=ax, grid=True,
    xlabel='Re(Z)', ylabel='-Im(Z)')
    f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
    f_data = f_data[['freq', 'Re(Z)', 'Im(Z)']]
    # cols = {'Re(Z)':'Re(Z)/Ohm', 'Im(Z)':'-Im(Z)/Ohm', 'freq':'freq/Hz'}
    # f_data.rename(columns=cols, inplace=True)

    f_data.to_csv(root / f"filtered/lon/{i}.csv", sep=",", header=False, index=False)

    # fig.savefig(root / f"nyquist/lon/doc_{sample}_{i}.png")
    # f_data = f_data[['Re(Z)', 'Im(Z)', 'freq']]
    # f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
    # f_data.to_csv(root / f"csv/lon/doc_{state}_{i}.txt", sep="\t", header=False, index=False)
    # with open(root / f"csv/lon/doc_{i}.txt", 'r+') as f:
    #     content = f.read()
    #     f.seek(0, 0)
    #     f.write('22' + '\n' + content)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14636\4117179799.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
# C:\Users\User\AppData\Local\Temp\ipykernel_14636\4117179799.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
# C:\Users\User\AppData\Local\Temp\ipykernel_14636\4117179799.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
# C:\Users\User\AppData\Local\Temp\ipykernel_14636\4117179799.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
# C:\Users\User\AppData\Local\Temp\ipykernel_14636\4117179799.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
# C:\Users\User\AppData\Local\Temp\ipykernel_14636\4117179799.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
# C:\Users\User\AppData\Local\Temp\ipykernel_14636\4117179799.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
# C:\Users\User\AppData\Local\Temp\ipykernel_14636\4117179799.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
# C:\Users\User\AppData\Local\Temp\ipykernel_14636\4117179799.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
# C:\Users\User\AppData\Local\Temp\ipykernel_14636\4117179799.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['Im(Z)'] = f_data['Im(Z)']*(-1)

# %%
# import math as m
# directory = root / 'Bode03.csv'
# df = pd.read_csv(directory)
# df["mag"] = df["CH2 Amplitude(V)"]
# df["CH2 Phase(Deg)"] = -np.radians(df["CH2 Phase(Deg)"])
# Vin = 2
# # x = pow(m.cos(df["CH2 Phase(Deg)"]) - df["CH2 Amplitude(dB)"] / Vin, 2) + pow(m.sin(df["CH2 Phase(Deg)"]), 2)
# df["ReZ"] = 12280 * (df["mag"] / Vin) * ((np.cos(df["CH2 Phase(Deg)"]) - (df["mag"] / Vin)) / (pow(np.cos(df["CH2 Phase(Deg)"]) - df["mag"] / Vin, 2) + pow(np.sin(df["CH2 Phase(Deg)"]), 2)))
#
# df["ImZ"] = 12280 * (df["mag"] / Vin) * (-np.sin(df["CH2 Phase(Deg)"]) / (pow(np.cos(df["CH2 Phase(Deg)"]) - df["mag"] / Vin, 2) + pow(np.sin(df["CH2 Phase(Deg)"]), 2)))
# df["ImZ"] = -df["ImZ"]
# df = df[df["ImZ"] < 2500]
# df.head()
# df.to_csv(root / 'test.csv', header=True, index=False)

# %%
df.plot.scatter(x='ReZ', y='ImZ', legend=True, label=f'', grid=True,
    xlabel='Re(Z)', ylabel='-Im(Z)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Linh Python\CoSoDien\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ReZ'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.plot.scatter(x='ReZ', y='ImZ', legend=True, label=f'', grid=True,
#       2     xlabel='Re(Z)', ylabel='-Im(Z)')
#
# File D:\Linh Python\CoSoDien\.venv\Lib\site-packages\pandas\plotting\_core.py:1748, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1660 def scatter(
#    1661     self,
#    1662     x: Hashable,
#    (...)   1666     **kwargs,
#    1667 ) -> PlotAccessor:
#    1668     """
#    1669     Create a scatter plot with varying marker point size and color.
#    1670
#    (...)   1746         ...                       colormap='viridis')
#    1747     """
# -> 1748     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File D:\Linh Python\CoSoDien\.venv\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File D:\Linh Python\CoSoDien\.venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File D:\Linh Python\CoSoDien\.venv\Lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File D:\Linh Python\CoSoDien\.venv\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1352, in ScatterPlot._make_plot(self, fig)
#    1349 else:
#    1350     label = None
#    1351 scatter = ax.scatter(
# -> 1352     data[x].values,
#    1353     data[y].values,
#    1354     c=c_values,
#    1355     label=label,
#    1356     cmap=cmap,
#    1357     norm=norm,
#    1358     s=self.s,
#    1359     **self.kwds,
#    1360 )
#    1361 if cb:
#    1362     cbar_label = c if c_is_column else ""
#
# File D:\Linh Python\CoSoDien\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File D:\Linh Python\CoSoDien\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'ReZ'

# %%
filename = root / "c1.csv"
from scipy.stats import zscore

df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)
df = df[df['Im(Z)'] < 4000]

def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    return df[(df[column] >= Q1 - 1.5 * IQR) & (df[column] <= Q3 + 1.5 * IQR)]

state = '0_0'
for i in range(1, 9):
    df1= df[(df['type'] == 'doc') & (df['state'] == state) & (df['sample'] == i) & (df['Im(Z)'] < 4000) & (df['freq'] > 30)]

# Apply to impedance and phase
    df_clean = remove_outliers(df1, 'Re(Z)')
    df_clean = remove_outliers(df_clean, 'Im(Z)')
    df_clean = remove_outliers(df_clean, 'phase')

    # df_clean[['Re(Z)', 'Im(Z)', 'phase']].boxplot()
    plt.figure()
    plt.scatter(df1["Re(Z)"], df1["Im(Z)"], label="Raw Data", color="red")
    plt.scatter(df_clean["Re(Z)"], df_clean["Im(Z)"], label="Filtered Data", color="blue")
    plt.xlabel("Re(Z)")
    plt.ylabel("-Im(Z)")
    plt.legend()
    plt.grid(True)
    plt.title("Nyquist Plot (Filtered & Smoothed)")
    plt.show()

# %%
filename = root / "c1.csv"
from scipy.ndimage import median_filter
from scipy.signal import savgol_filter

df = pd.read_csv(filename, usecols=['freq', 'Z', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df['Im(Z)'] = df['Im(Z)'] * (-1)
df['freq'] = pd.to_numeric(df['freq'], errors='coerce')
state_list = ['0_0', '1_0', '2_0']
# fig, ax = plt.subplots()
# fig1, ax1 = plt.subplots()
for k in range(1, 9):
    fig, ax = plt.subplots()
    # fig1, ax1 = plt.subplots()
    for i in range(len(state_list)):

        f_data = df[(df['type'] == 'doc') & (df['state'] == state_list[i]) & (df['sample'] == k) & (df['freq'] > 30)]

        Q1 = f_data['Z'].quantile(0.25)
        Q3 = f_data['Z'].quantile(0.75)
        IQR = Q3 - Q1

        # Filter out outliers
        df_clean = f_data[(f_data['Z'] >= Q1 - 1.5 * IQR) & (f_data['Z'] <= Q3 + 1.5 * IQR)]

        df_clean['Z'] = median_filter(df_clean['Z'], size=9)
        # df_clean['Z'] = savgol_filter(df_clean['Z'], window_length=5, polyorder=2)
        # df['Z'] = df['Z'].rolling(window=5).mean()

        # df['phase'] = median_filter(df['phase'], size=5)

        # z_scores = np.abs((f_data["Z"] - f_data["Z"].mean()) / f_data["Z"].std())
        # df_filtered = f_data[z_scores < 2]
        # df_filtered.interpolate(method='linear', inplace=True)

        df_clean.plot(x='freq', y='Z', legend=False, label=f'Z', ax=ax, grid=True, logx=True)
        # df_clean.plot(x='freq', y='phase', legend=False, label=f'Z', ax=ax, grid=True, logx=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def moving_average(data, window_size=5):
    return np.convolve(data, np.ones(window_size)/window_size, mode='same')

# --- Your existing setup ---
import pathlib as pl
root = pl.Path("D:/Linh Python/Cosodien")
filename = root / "c2.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df['Im(Z)'] = df['Im(Z)'] * (-1)
df['freq'] = pd.to_numeric(df['freq'], errors='coerce')
state_list = ['0_0', '1_0', '2_0']

# --- Apply smoothing & plot ---
for k in range(1, 11):
    fig, ax = plt.subplots()
    fig1, ax1 = plt.subplots()

    for state in state_list:
        f_data = df[(df['type'] == 'doc') & (df['state'] == state) & (df['sample'] == k) & (df['freq'] > 30)]

        # Apply smoothing
        freq = f_data['freq'].values
        re_z = moving_average(f_data['Re(Z)'].values)
        im_z = moving_average(f_data['Im(Z)'].values)

        ax.plot(freq, re_z, label=f'{state}', marker='o')
        ax.set_xscale('log')
        ax.set_xlabel('freq(Hz)')
        ax.set_ylabel('Re(Z)')
        ax.grid(True)

        ax1.plot(freq, im_z, label=f'{state}', marker='o')
        ax1.set_xscale('log')
        ax1.set_xlabel('freq(Hz)')
        ax1.set_ylabel('-Im(Z)')
        ax1.grid(True)

    ax.legend()
    ax1.legend()
