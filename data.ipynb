# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pathlib as pl

# %%
#nyquist plot
root = pl.Path("C:/Users/LENOVO/PycharmProjects/PythonProject/cosodien")
filename = root / "c1.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)
match int(df['state'][0]):
    case 0: state_label = "ngay 1"
    case 1: state_label = "ngay 2"
    case 2: state_label = "ngam"

state = '0_0'
fig, ax = plt.subplots()
for i in range(1, 6):

    f_data = df[(df['type'] == 'doc') & (df['state'] == state) & (df['sample'] == i)]
    # f_data['freq'] = [20, 200, 2000, 20000, 200000][:len(f_data)]

    f_data.plot(x='Re(Z)', y='Im(Z)', legend=True, label=f'sample {i}', ax=ax, grid=True,
    xlabel='Re(Z)', ylabel='-Im(Z)')

# %%
#phase bode plot
# root = pl.Path("D:/Linh Python/Cosodien")
filename = root / "c1.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'Z', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)
df["phase"] = df["phase"] * (-1)
match int(df['state'][0]):
    case 0: state_label = "ngay 1"
    case 1: state_label = "ngay 2"
    case 2: state_label = "ngam"

state_list = ['0_0', '1_0', '2_0']
for k in range(1, 9):
    fig, ax = plt.subplots()
    for i in range(len(state_list)):

        f_data = df[(df['type'] == 'doc') & (df['state'] == state_list[i]) & (df['sample'] == k)]

        f_data.plot(x='freq', y='phase', legend=True, label=f'{i}_0', ax=ax, grid=True,
        xlabel='freq', ylabel='phase(deg)', logx=True)
        fig.savefig(root / f'phase/ga/sample{k}.png')

# %%
#magnitude bode plot
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'Z', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)

state = '0_0'
state_list = ['0_0', '1_0', '2_0']
df['freq'] = pd.to_numeric(df['freq'], errors='coerce')
fig, ax = plt.subplots()
for i in range(1, 9):

    f_data = df[(df['type'] == 'doc') & (df['state'] == state) & (df['sample'] == i) & (df['freq'] > 40)]

    f_data.plot(x='freq', y='Z', legend=True, label=f'{i}_0', ax=ax, grid=True,
    xlabel='freq', ylabel='phase(deg)', logx=True)

# %%
# root = pl.Path("D:/Linh Python/Cosodien")
filename = root / "p1.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df['Im(Z)'] = df['Im(Z)'] * (-1)
df['freq'] = pd.to_numeric(df['freq'], errors='coerce')
state_list = ['0_0', '1_0', '2_0']
# fig, ax = plt.subplots()
# fig1, ax1 = plt.subplots()
for k in range(1, 11):
    fig, ax = plt.subplots()
    fig1, ax1 = plt.subplots()
    for i in range(len(state_list)):

        f_data = df[(df['type'] == 'doc') & (df['state'] == state_list[i]) & (df['sample'] == k) & (df['freq'] > 30)]

        # f_data.plot(x='freq', y='Im(Z)', legend=True, label=f'-Im(Z)', ax=ax, grid=True, marker='o', logx=True)
        f_data.plot(x='freq', y='Re(Z)', legend=False, label=f'Re(Z)', ax=ax, grid=True, logx=True)
        fig.savefig(root / f"magnitude/lon/Re{k}.png")

    for i in range(len(state_list)):

        f_data = df[(df['type'] == 'doc') & (df['state'] == state_list[i]) & (df['sample'] == k) & (df['freq'] > 30)]

        # f_data.plot(x='freq', y='Im(Z)', legend=True, label=f'-Im(Z)', ax=ax, grid=True, marker='o', logx=True)
        f_data.plot(x='freq', y='Im(Z)', legend=False, label=f'-Im(Z)', ax=ax1, grid=True, logx=True)
        fig.savefig(root / f"magnitude/lon/Im{k}.png")

# %%
filename = root / "p1.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)

state = '0_0'
for i in range(1, 11):
    fig, ax = plt.subplots()
    f_data = df[(df['type'] == 'doc') & (df['state'] == state) & (df['sample'] == i)]

    f_data.plot.scatter(x='Re(Z)', y='Im(Z)', legend=True, label=f'sample', ax=ax, grid=True,
    xlabel='Re(Z)', ylabel='-Im(Z)')
    f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
    f_data = f_data[['freq', 'Re(Z)', 'Im(Z)']]
    # cols = {'Re(Z)':'Re(Z)/Ohm', 'Im(Z)':'-Im(Z)/Ohm', 'freq':'freq/Hz'}
    # f_data.rename(columns=cols, inplace=True)

    # f_data.to_csv(root / f"final_format/lon/{i}.csv", sep=",", header=False, index=False)

    # fig.savefig(root / f"nyquist/lon/doc_{sample}_{i}.png")
    # f_data = f_data[['Re(Z)', 'Im(Z)', 'freq']]
    # f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
    # f_data.to_csv(root / f"csv/lon/doc_{state}_{i}.txt", sep="\t", header=False, index=False)
    # with open(root / f"csv/lon/doc_{i}.txt", 'r+') as f:
    #     content = f.read()
    #     f.seek(0, 0)
    #     f.write('22' + '\n' + content)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\2442761294.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\2442761294.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\2442761294.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
filename = root / "c1.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)

state = '0_0'

for i in range(1, 9):
    fig, ax = plt.subplots()
    f_data = df[(df['type'] == 'ngang') & (df['state'] == state) & (df['sample'] == i)]
    f_data = f_data[f_data['Im(Z)'] < 4000]

    f_data.plot.scatter(x='Re(Z)', y='Im(Z)', legend=True, label=f'{state}', ax=ax, grid=True,
    xlabel='Re(Z)', ylabel='-Im(Z)')
    # fig.savefig(root / f"nyquist/ga/doc_{state}_date_{i}.png")
    f_data['Im(Z)'] = f_data['Im(Z)']*(-1)
    f_data = f_data[['freq', 'Re(Z)', 'Im(Z)']]
    # cols = {'Re(Z)':'Re(Z)/Ohm', 'Im(Z)':'-Im(Z)/Ohm', 'freq':'freq/Hz'}
    # f_data.rename(columns=cols, inplace=True)
    f_data.to_csv(root / f"filtered/ga/{i}.csv", sep=",", header=False, index=False)
    # f_data.to_csv(root / f"csv/ga/doc_{i}.txt", sep="\t", header=False, index=False)
    # with open(root / f"csv/ga/doc_{i}_state{state}.txt", 'r+') as f:
    #     content = f.read()
    #     f.seek(0, 0)
    #     f.write('22' + '\n' + content)

# %%
#phase bode plot
# root = pl.Path("D:/Linh Python/Cosodien")
filename = root / "P1.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'Z', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)
df["phase"] = df["phase"] * (-1)
match int(df['state'][0]):
    case 0: state_label = "ngay 1"
    case 1: state_label = "ngay 2"
    case 2: state_label = "ngam"

state_list = ['0_0', '1_0', '2_0']
for k in range(1, 9):
    fig, ax = plt.subplots()
    for i in range(len(state_list)):

        f_data = df[(df['type'] == 'doc') & (df['state'] == state_list[i]) & (df['sample'] == k) & (df['freq'] > 30)]

        f_data.plot(x='freq', y='phase', legend=True, label=f'{i}_0', ax=ax, grid=True,
        xlabel='freq', ylabel='phase(deg)', logx=True)
        fig.savefig(root / f'phase/ga/sample{k}.png')

# %%
# root = pl.Path("D:/Linh Python/Cosodien")
from scipy.interpolate import UnivariateSpline
filename = root / "c1.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df['Im(Z)'] = df['Im(Z)'] * (-1)
df['freq'] = pd.to_numeric(df['freq'], errors='coerce')
state_list = ['0_0', '1_0', '2_0']
# fig, ax = plt.subplots()
# fig1, ax1 = plt.subplots()
for k in range(1, 9):
    fig, ax = plt.subplots()
    fig1, ax1 = plt.subplots()
    for i in range(len(state_list)):

        f_data = df[(df['type'] == 'doc') & (df['state'] == state_list[i]) & (df['sample'] == k) & (df['freq'] > 30)]
        # spline_real = UnivariateSpline(f_data["freq"], f_data["Re(Z)"], s=0.5)
        # f_data.interpolate(method="linear", inplace=True)
        z_scores = np.abs((f_data["Re(Z)"] - f_data["Re(Z)"].mean()) / f_data["Re(Z)"].std())
        df_filtered = f_data[z_scores < 2]
        df_filtered.interpolate(method='linear', inplace=True)

        # f_data.plot(x='freq', y='Im(Z)', legend=True, label=f'-Im(Z)', ax=ax, grid=True, marker='o', logx=True)
        df_filtered.plot(x='freq', y='Re(Z)', legend=False, label=f'Re(Z)', ax=ax, grid=True, logx=True)
        fig.savefig(root / f"magnitude/ga/Re{k}.png")

    for i in range(len(state_list)):

        f_data = df[(df['type'] == 'doc') & (df['state'] == state_list[i]) & (df['sample'] == k) & (df['freq'] > 30)]
        z_scores = np.abs((f_data["Im(Z)"] - f_data["Im(Z)"].mean()) / f_data["Im(Z)"].std())
        df_filtered = f_data[z_scores < 2]
        df_filtered.interpolate(method='cubic',order=3, inplace=True)
        # f_data.plot(x='freq', y='Im(Z)', legend=True, label=f'-Im(Z)', ax=ax, grid=True, marker='o', logx=True)
        df_filtered.plot(x='freq', y='Im(Z)', legend=False, label=f'-Im(Z)', ax=ax1, grid=True, logx=True)
        fig.savefig(root / f"magnitude/ga/Im{k}.png")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\55045109.py:20: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_filtered.interpolate(method='linear', inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\55045109.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.interpolate(method='linear', inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\55045109.py:20: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_filtered.interpolate(method='linear', inplace=True)
# ...

# %%
filename = root / "p.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)

state = '2_0'
for i in range(1, 6):
    fig, ax = plt.subplots()
    f_data = df[(df['type'] == 'doc') & (df['state'] == state) & (df['sample'] == i) & df['freq'] > 30]

    f_data.plot.scatter(x='Re(Z)', y='Im(Z)', legend=True, label=f'{state}', ax=ax, grid=True,
    xlabel='Re(Z)', ylabel='-Im(Z)')
    # fig.savefig(root / f"nyquist/lon/doc_{state}_date_{i}.png")
    f_data = f_data[['freq', 'Re(Z)', 'Im(Z)']]
    f_data["Im(Z)"] = f_data["Im(Z)"] * (-1)
    f_data.to_csv(root/ f'final_format/lon/{state}_{i}.csv', header=False, index=False)

# %%
import pathlib as pl
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter
from scipy.interpolate import UnivariateSpline

import matplotlib.pyplot as plt
from scipy import interpolate
s = 0.3

# root = pl.Path("D:/Linh Python/Cosodien")
filename = root / "c1.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)
df = df[df['Im(Z)'] < 4000]

state = '0_0'
for i in range(1, 9):
    df1= df[(df['type'] == 'ngang') & (df['state'] == state) & (df['sample'] == i) & (df['Im(Z)'] < 4000) & (df['freq'] > 30)]
    # Q1 = df1["Re(Z)"].quantile(0.25)
    # Q3 = df1["Re(Z)"].quantile(0.75)
    # IQR = Q3 - Q1
    # df_filtered = df1[(df1["Re(Z)"] >= Q1 - 1.5 * IQR) & (df1["Re(Z)"] <= Q3 + 1.5 * IQR)]
    z_scores = np.abs((df1["Im(Z)"] - df1["Im(Z)"].mean()) / df1["Im(Z)"].std())
    df_filtered = df1[z_scores < 2]
    df_filtered = df_filtered[df_filtered["Im(Z)"] < 4000]


    # df_filtered["Re(Z)"] = savgol_filter(df_filtered["Re(Z)"], window_length=5, polyorder=2)
    # df_filtered["Im(Z)"] = savgol_filter(df_filtered["Im(Z)"], window_length=5, polyorder=2)

    # spline_real = UnivariateSpline(df_filtered["freq"], df_filtered["Re(Z)"], s=0.5)
    # spline_imag = UnivariateSpline(df_filtered["freq"], df_filtered["Im(Z)"], s=0.5)
    # f_new = np.linspace(df_filtered["freq"].min(), df_filtered["freq"].max(), 100)
    # Z_real_spline = spline_real(f_new)
    # Z_imag_spline = spline_imag(f_new)
    df_filtered.interpolate(method="spline", order=3, inplace=True)
    df_filtered = df_filtered[["freq", "Re(Z)", "Im(Z)"]]

    plt.figure()
    plt.scatter(df1["Re(Z)"], df1["Im(Z)"], label="Raw Data", color="red")
    plt.scatter(df_filtered["Re(Z)"], df_filtered["Im(Z)"], label="Filtered Data", color="blue")
    plt.xlabel("Re(Z)")
    plt.ylabel("-Im(Z)")
    plt.legend()
    plt.grid(True)
    plt.title("Nyquist Plot (Filtered & Smoothed)")
    plt.show()

    df_filtered["Im(Z)"] = df_filtered["Im(Z)"] * (-1)
    df_filtered.to_csv(root / f"filtered/ga/{i}.csv", header=False, index=False)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\2372551580.py:37: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_filtered.interpolate(method="spline", order=3, inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\2372551580.py:37: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_filtered.interpolate(method="spline", order=3, inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\2372551580.py:37: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_filtered.interpolate(method="spline", order=3, inplace=True)
# ...

# %%
import pathlib as pl
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter
from scipy.interpolate import UnivariateSpline

import matplotlib.pyplot as plt
from scipy import interpolate
s = 0.3

# root = pl.Path("D:/Linh Python/Cosodien")
filename = root / "p1.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)

state = '0_0'
for i in range(1, 11):
    df1= df[(df['type'] == 'doc') & (df['state'] == state) & (df['sample'] == i) & (df['Im(Z)'] < 4000) & (df['freq'] > 30)]
    # Q1 = df1["Re(Z)"].quantile(0.25)
    # Q3 = df1["Re(Z)"].quantile(0.75)
    # IQR = Q3 - Q1
    # df_filtered = df1[(df1["Re(Z)"] >= Q1 - 1.5 * IQR) & (df1["Re(Z)"] <= Q3 + 1.5 * IQR)]
    z_scores = np.abs((df1["Im(Z)"] - df1["Im(Z)"].mean()) / df1["Im(Z)"].std())
    df_filtered = df1[z_scores < 3]
    # df_filtered = df_filtered[df_filtered["Im(Z)"] > 250]


    df_filtered["Re(Z)"] = savgol_filter(df_filtered["Re(Z)"], window_length=5, polyorder=2)
    df_filtered["Im(Z)"] = savgol_filter(df_filtered["Im(Z)"], window_length=5, polyorder=2)

    # spline_real = UnivariateSpline(df_filtered["freq"], df_filtered["Re(Z)"], s=0.5)
    # spline_imag = UnivariateSpline(df_filtered["freq"], df_filtered["Im(Z)"], s=0.5)
    # f_new = np.linspace(df_filtered["freq"].min(), df_filtered["freq"].max(), 100)
    # Z_real_spline = spline_real(f_new)
    # Z_imag_spline = spline_imag(f_new)
    df_filtered.interpolate(method="spline", order=3, inplace=True)
    df_filtered = df_filtered[["freq", "Re(Z)", "Im(Z)"]]

    plt.figure()
    plt.scatter(df1["Re(Z)"], df1["Im(Z)"], label="Raw Data", color="red")
    plt.scatter(df_filtered["Re(Z)"], df_filtered["Im(Z)"], label="Filtered Data", color="blue")
    plt.xlabel("Re(Z)")
    plt.ylabel("-Im(Z)")
    plt.legend()
    plt.grid(True)
    plt.title("Nyquist Plot (Filtered & Smoothed)")
    plt.show()

    df_filtered["Im(Z)"] = df_filtered["Im(Z)"] * (-1)
    # df_filtered.to_csv(root / f"filtered/lon/{i}.csv", header=False, index=False)

    # df1['Re(Z)'] = savgol_filter(df1['Re(Z)'], window_length=5, polyorder=2)  # Smooth noisy data
    # df1['Im(Z)'] = savgol_filter(df1['Im(Z)'], window_length=5, polyorder=2)
    # df1.plot.scatter(x='Re(Z)', y='Im(Z)', legend=True, label=f'{state}', ax=ax, grid=True,
    # xlabel='Re(Z)', ylabel='-Im(Z)')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\179673736.py:36: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_filtered.interpolate(method="spline", order=3, inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\179673736.py:36: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_filtered.interpolate(method="spline", order=3, inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\179673736.py:36: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_filtered.interpolate(method="spline", order=3, inplace=True)
# ...

# %%
        # fig.savefig(root / f"magnitude/ga/Im{k}.png")
filename = root / "p.csv"
df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)

state = '2_0'
fig, ax = plt.subplots()
f_data = df[(df['type'] == 'doc') & (df['state'] == state) & (df['sample'] == 4)]

f_data.plot.scatter(x='Re(Z)', y='Im(Z)', legend=True, label=f'{state}', ax=ax, grid=True,
                    xlabel='Re(Z)', ylabel='-Im(Z)')
# fig.savefig(root / f"nyquist/lon/doc_{state}_date_{i}.png")
f_data = f_data[['freq', 'Re(Z)', 'Im(Z)']]
f_data["Im(Z)"] = f_data["Im(Z)"] * (-1)
f_data.to_csv(root / f'{state}_{4}.csv', header=False, index=False)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\91456876.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_data["Im(Z)"] = f_data["Im(Z)"] * (-1)

# %%
# import math as m
# directory = root / 'Bode03.csv'
# df = pd.read_csv(directory)
# df["mag"] = df["CH2 Amplitude(V)"]
# df["CH2 Phase(Deg)"] = -np.radians(df["CH2 Phase(Deg)"])
# Vin = 2
# # x = pow(m.cos(df["CH2 Phase(Deg)"]) - df["CH2 Amplitude(dB)"] / Vin, 2) + pow(m.sin(df["CH2 Phase(Deg)"]), 2)
# df["ReZ"] = 12280 * (df["mag"] / Vin) * ((np.cos(df["CH2 Phase(Deg)"]) - (df["mag"] / Vin)) / (pow(np.cos(df["CH2 Phase(Deg)"]) - df["mag"] / Vin, 2) + pow(np.sin(df["CH2 Phase(Deg)"]), 2)))
#
# df["ImZ"] = 12280 * (df["mag"] / Vin) * (-np.sin(df["CH2 Phase(Deg)"]) / (pow(np.cos(df["CH2 Phase(Deg)"]) - df["mag"] / Vin, 2) + pow(np.sin(df["CH2 Phase(Deg)"]), 2)))
# df["ImZ"] = -df["ImZ"]
# df = df[df["ImZ"] < 2500]
# df.head()
# df.to_csv(root / 'test.csv', header=True, index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[96], line 3
#       1 import math as m
#       2 directory = root / 'Bode03.csv'
# ----> 3 df = pd.read_csv(directory)
#       4 df["mag"] = df["CH2 Amplitude(V)"]
#       5 df["CH2 Phase(Deg)"] = -np.radians(df["CH2 Phase(Deg)"])
#
# ...

# %%
df.plot.scatter(x='ReZ', y='ImZ', legend=True, label=f'', grid=True,
    xlabel='Re(Z)', ylabel='-Im(Z)')
# Out:
# <Axes: xlabel='Re(Z)', ylabel='-Im(Z)'>

# %%
filename = root / "c1.csv"
from scipy.stats import zscore

df = pd.read_csv(filename, usecols=['freq', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df["Im(Z)"] = df["Im(Z)"] * (-1)
df = df[df['Im(Z)'] < 4000]

def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    return df[(df[column] >= Q1 - 1.5 * IQR) & (df[column] <= Q3 + 1.5 * IQR)]

state = '0_0'
for i in range(1, 9):
    df1= df[(df['type'] == 'doc') & (df['state'] == state) & (df['sample'] == i) & (df['Im(Z)'] < 4000) & (df['freq'] > 30)]

# Apply to impedance and phase
    df_clean = remove_outliers(df1, 'Re(Z)')
    df_clean = remove_outliers(df_clean, 'Im(Z)')
    df_clean = remove_outliers(df_clean, 'phase')

    # df_clean[['Re(Z)', 'Im(Z)', 'phase']].boxplot()
    plt.figure()
    plt.scatter(df1["Re(Z)"], df1["Im(Z)"], label="Raw Data", color="red")
    plt.scatter(df_clean["Re(Z)"], df_clean["Im(Z)"], label="Filtered Data", color="blue")
    plt.xlabel("Re(Z)")
    plt.ylabel("-Im(Z)")
    plt.legend()
    plt.grid(True)
    plt.title("Nyquist Plot (Filtered & Smoothed)")
    plt.show()

# %%
filename = root / "c1.csv"
from scipy.ndimage import median_filter
from scipy.signal import savgol_filter

df = pd.read_csv(filename, usecols=['freq', 'Z', 'Re(Z)', 'Im(Z)', 'phase', 'type', 'state', 'sample'])
df['Im(Z)'] = df['Im(Z)'] * (-1)
df['freq'] = pd.to_numeric(df['freq'], errors='coerce')
state_list = ['0_0', '1_0', '2_0']
# fig, ax = plt.subplots()
# fig1, ax1 = plt.subplots()
for k in range(1, 9):
    fig, ax = plt.subplots()
    # fig1, ax1 = plt.subplots()
    for i in range(len(state_list)):

        f_data = df[(df['type'] == 'doc') & (df['state'] == state_list[i]) & (df['sample'] == k) & (df['freq'] > 30)]

        Q1 = f_data['Z'].quantile(0.25)
        Q3 = f_data['Z'].quantile(0.75)
        IQR = Q3 - Q1

        # Filter out outliers
        df_clean = f_data[(f_data['Z'] >= Q1 - 1.5 * IQR) & (f_data['Z'] <= Q3 + 1.5 * IQR)]

        df_clean['Z'] = median_filter(df_clean['Z'], size=9)
        # df_clean['Z'] = savgol_filter(df_clean['Z'], window_length=5, polyorder=2)
        # df['Z'] = df['Z'].rolling(window=5).mean()

        # df['phase'] = median_filter(df['phase'], size=5)

        # z_scores = np.abs((f_data["Z"] - f_data["Z"].mean()) / f_data["Z"].std())
        # df_filtered = f_data[z_scores < 2]
        # df_filtered.interpolate(method='linear', inplace=True)

        df_clean.plot(x='freq', y='Z', legend=False, label=f'Z', ax=ax, grid=True, logx=True)
        # df_clean.plot(x='freq', y='phase', legend=False, label=f'Z', ax=ax, grid=True, logx=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Z'] = median_filter(df_clean['Z'], size=9)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17488\487379136.py:25: SettingWithCopyWarning:
# ...
